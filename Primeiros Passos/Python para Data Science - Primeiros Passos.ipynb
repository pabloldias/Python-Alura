# %% [markdown]
# #  Função e linguagem de alto nível

# %%
def nome_completo():
 primeiro_nome = input('Qual seu primeiro nome? ')
 sobrenome = input('Qual seu sobrenome? ')
 nome_inteiro = primeiro_nome + ' ' + sobrenome
 print(nome_inteiro)

nome_completo()
# Out:
# Qual seu primeiro nome? Pablo
# Qual seu sobrenome? Dias
# Pablo Dias

# %% [markdown]
# ## Aula 2

# %%
def velocidade(espaco, tempo):
    v = espaco / tempo
    print(f'Velocidade: {v} m/s')

# %%
velocidade(50,100)
# Out:
# Velocidade: 0.5 m/s

# %%
def habilitacao():
 idade = input('Qual sua idade? ')
 idade = int(idade)
 if idade >= 18:
   print('Pode tirar habilitação')
 else:
   tempo = 18 - idade
   print(f'Calma... espere {tempo} ano(s) para tirar habilitação')

habilitacao()
# Out:
# Qual sua idade? 12
# Calma... espere 6 ano(s) para tirar habilitação

# %% [markdown]
# ## Aula 3

# %%
frases_alura = [' Digitais', 'e ', 'Negócios ', 'de ', 'Tecnologia ', 'Cursos ']

# %%
frases_alura[-1] + frases_alura[3] + frases_alura[4] + frases_alura[1] + frases_alura[2] + frases_alura[0]
# Out:
# 'Cursos de Tecnologia e Negócios  Digitais'

# %%
a=2

if a < 2:
 a = a + 1
else:
 a = a + 2
if a < 4:
 a = a - 4
else:
 a = a + 6

a
# Out:
# 10

# %% [markdown]
# # Aula 4, já era! Agora é aula 5, aula 5, aula 5

# %%
import matplotlib.pyplot as plt

notas_matematica = ['Matemática',8,7,6,6,7,7,8,10]
notas_portugues = ['Português',9,9,9,8,5,6,8,5]
notas_geografia = ['Geografia',10,10,6,7,7,7,8,7]

notas = [notas_matematica, notas_portugues, notas_geografia]

# %%
for nota in notas:
 x = list(range(1, 9))
 y = nota[1:]
 plt.plot(x, y, marker='o')
 plt.xlabel('Provas')
 plt.ylabel('Notas')
 plt.title(nota[0])
 plt.show()

# %%
r = range(1,9)
type(r)
# Out:
# range
